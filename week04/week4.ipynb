# %% [markdown]
# W4A1

# %%
#for
n = int(input())
sum = 0
for i in range(1, n + 1):
    sum += i
print(sum)
# Out:
# 21

# %%
#while
n = int(input())
sum = 0
while n>=0:
    sum += n
    n -= 1
print(sum)
# Out:
# 6

# %% [markdown]
# W4A2

# %%
n = -1
while n <= 0:
    n = int(input())
c = 1
for i in range(2, int(n**(0.5))+1): 
    if n%i == 0:
        c = 0
        break
print(bool(c))
# Out:
# False

# %% [markdown]
# W4A3

# %%
#for
n = int(input())
giai_thua = 1
for i in range(1, n + 1):
    giai_thua *= i
print(giai_thua)
# Out:
# 24

# %%
#dq
def giai_thua(n):
    if n == 0 or n == 1:
        return 1
    else:
        return n * giai_thua(n - 1)
n = int(input())
print(giai_thua(n))
# Out:
# 24

# %% [markdown]
# W4A4

# %%
a = abs(int((input())))
if a == 0:
    print(1)
else:
    cnt = 0
    while a > 0:
        cnt += 1
        a //= 10
    print(cnt)
# Out:
# 7

# %% [markdown]
# W4A5

# %%
n = int(input())
c = 0
for i in range(1, n + 1):
    a = int(input())
    if a == 42: c = 1
if c: print("I've found the meaning of life!")
else: print("It's a joke!")
# Out:
# I've found the meaning of life!

# %% [markdown]
# W4A6

# %%
a, b = map(int, input().split())
sum = 0
for i in range(a, b + 1):
    c=1
    for j in range(2, int(i**(0.5))+1):
        if i%j == 0:
            c=0
            break
    if c: sum+=i
print(sum)
# Out:
# 533

# %% [markdown]
# W4A7

# %%
n = int(input())
for i in range(n, 1, -1):
    c=1
    for j in range(2, int(i**(0.5))+1):
        if i%j == 0:
            c=0
            break
    if c and n%i == 0:
        print(i)
        break
# Out:
# 99991

# %% [markdown]
# W4A8

# %%
n = input()
cnt = 0
rev_n = int(n[::-1])
n = int(n)
while n != rev_n:
    n += rev_n
    rev_n = int(str(n)[::-1])
    cnt+=1
print(cnt, n)
# Out:
# 24 8813200023188

# %% [markdown]
# W4A9

# %%
n = int(input())
for i in range(1, n+1):
    if int(i**0.5)**2 == i:
        print(i, end=' ')
# Out:
# 1 4 9

# %% [markdown]
# W4A10

# %%
n = int(input())
cnt = 1
ans = 0
for i in range(1, n + 1):
    cnt1 = 1
    j = i
    while j!=1:
        if j%2 == 0:
            j//=2
            cnt1+=1
        else:
            j=3*j+1
            cnt1+=1
    if cnt1 > cnt:
        ans = i
        cnt = cnt1
print(ans, cnt)
# Out:
# 171 125

# %% [markdown]
# W4A11

# %%
n = int(input())
cnt = 0
for i in range(2, n + 1, 2):
    if n%i == 0:
        cnt+=1
print(cnt)
# Out:
# 2

# %% [markdown]
# W4A12

# %%
x, n = map(int, input().split())
print(int(x*(1+0.007)**n))
# Out:
# 10902

# %% [markdown]
# W4A13

# %%
a, b = map(int, input().split())
sum_a = 0
sum_b = 0
for i in range (1, a):
    if (a % i == 0): sum_a += i
if sum_a == b:
    for i in range (1, b):
        if (b % i == 0): sum_b += i
    if sum_b == a:
        print("true")
else:
    print("false")
# Out:
# true

# %% [markdown]
# W4A14

# %%
m, n = map(int, input().split())
for i in range(max(m, n), 0, -1):
    if m%i == 0 and n%i == 0:
        print(i)
        break
# Out:
# 4

# %% [markdown]
# W4A15

# %%
m, n = map(int, input().split())
if m % 2 != 0 or n % 2 != 0:
    print("invalid")
else:
    y = n/2-m
    x = m - y
    print(int(x), int(y))
# Out:
# 59 19

# %% [markdown]
# W4A16

# %%
for i in range(100):
    if i % 6 == 0:
        print(i)
# Out:
# 0
# 6
# 12
# 18
# 24
# 30
# 36
# 42
# 48
# 54
# 60
# 66
# 72
# 78
# 84
# 90
# 96

# %% [markdown]
# W4A17

# %%
a = int(input())
for i in range(1, 10):
    print(f"{a} x {i} = {a*i}")
# Out:
# 6 x 1 = 6
# 6 x 2 = 12
# 6 x 3 = 18
# 6 x 4 = 24
# 6 x 5 = 30
# 6 x 6 = 36
# 6 x 7 = 42
# 6 x 8 = 48
# 6 x 9 = 54

# %% [markdown]
# W4A18

# %%
a, b = map(int, input().split())
for i in range(1, max(a, b)+1):
    if a%i == 0 and b%i == 0:
        print(i)

# %% [markdown]
# W4A20

# %%
n = int(input())
def luythua2(n):
    if n == 1:
        return True
    else:
        while n > 1:
            if n % 2 != 0:
                return False
            n //= 2
    return True
print(luythua2(n))
# Out:
# False

# %% [markdown]
# W4A21

# %%
n = input()
sum = 0
for i in n:
    sum+=int(i)
print(sum)

# %% [markdown]
# W4A22

# %%
n = input()
cntc = 0
cntl = 0
for i in n:
    if int(i) % 2 == 0: cntc+=1
    else: cntl+=1
print(cntc, cntl)
# Out:
# 10

# %% [markdown]
# W4A23

# %%
n = int(input())
sum = 0
for i in range(1, n + 1):
    if sum + i >= n: break
    sum += i
print(sum)
# Out:
# 5 5

# %% [markdown]
# W4A24

# %%
n = int(input())
sum = 0
i=1
while sum <= n:
    sum += 1/i
    i+=1
print(i-1)
# Out:
# 227

# %% [markdown]
# W4A25

# %%
n = 0
while 1:
    n = int(input())
    if n == -1:
        break
    maxn = max(maxn, n)
    minn = min(minn, n)
print(maxn, minn)
# Out:
# 344 3

# %% [markdown]
# W4A26

# %%
a = int(input())
def fibo(a):
    if a == 0:
        return 0
    elif a == 1:
        return 1
    else:
        return fibo(a - 1) + fibo(a - 2)
i = 0
while fibo(i)<=a:
    i+=1
print(fibo(i-1))
# Out:
# 8

# %% [markdown]
# W4A27

# %%
n = input()
cnt = 0
for i in n:
    if i == ' ': cnt+=1
print(cnt)
# Out:
# 3

# %% [markdown]
# W4A28

# %%
n = input()
for i in n:
    print(i, end='')
    if i == ' ':
        break
# Out:
# 456

# %% [markdown]
# W4A29

# %%
n = input()
s = [0]*1000000 
sum = 0
j = 0
i = 0
while i < len(n):
    if n[i] != ',':
        s[j] = s[j] * 10 + int(n[i])
        i+=1
    else:
        i+=2
        j+=1
for i in range(j+1):
    sum += s[i]
print(sum)
# Out:
# 6

# %% [markdown]
# W4A30

# %%
a = input()
cnt_num = 0
cnt_char = 0
cnt_char_shift = 0
for i in a:
    if '0' <= i <= '9': cnt_num+=1
    if 'a' <= i <= 'z': cnt_char+=1
    if 'A' <= i <= 'Z': cnt_char_shift+=1
print(cnt_num, cnt_char, cnt_char_shift)
# Out:
# 6 6 7

# %% [markdown]
# W4A31

# %%
a = input()
sum = 0
for i in a:
    if '0' <= i <= '9': sum +=int(i)
print(sum)

# %% [markdown]
# W4A32

# %%
a = input()
c1 = 1
c2 = 1
c3 = 1
c4 = 1
if len(a) > 6: c1 = 0
for i in a:
    if '0' <= i <= '9': c2 = 0  
    if 'a' <= i <= 'z': c3 = 0
    if 'A' <= i <= 'Z': c4 = 0
if c1 == c2 == c3 == c4 == 0: print(True)
else: print(False)
# Out:
# True

# %% [markdown]
# W4A33

# %%
a = input()
print(a[0], end = '')
for i in range(1, len(a)):
    if (len(a) - i) % 3 == 0: print(".", end = '')
    print(a[i], end = '')
# Out:
# 123.456.789

# %% [markdown]
# W4A34

# %%
a = input()
b = input()
i = 0
while i < len(a):
    c = False
    if a[i] == b[0]:
        i1 = i
        c = True
        for j in range(len(b)):
            if a[i1] != b[j]: 
                c = False 
                break
            i1+=1
    if c: 
        i+=i1
        c = False
    print(a[i], end = '')
    i+=1
# Out:
# 456789
