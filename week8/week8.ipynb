# %% [markdown]
# A2

# %%
class date:
    def __init__(self, d, m, y):
        date.d = d
        date.m = m
        date.y = y
    def check_valid(self):
        m30 = [2, 4, 6, 9, 11]
        m31 = [1, 3, 5, 7, 8, 10, 12]
        if self.m<=12:
            if self.m == 2:
                if self.y % 4 == 0:
                    if self.y%400==0:
                        if self.d > 29:
                            return 'INVALID'
                    else:
                        return 'INVALID'
                else:
                    return 'INVALID'
            else:
                if self.m in m30:
                    if self.d >30:
                        return 'INVALID'
                elif self.d in m31:
                    if self.d >31:
                        return 'INVALID'
        else:
            return 'INVALID'
    #def next_day(self):
